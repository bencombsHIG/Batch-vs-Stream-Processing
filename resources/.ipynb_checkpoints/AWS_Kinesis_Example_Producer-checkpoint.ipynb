# %%
# if you run into an error you may need to run this twice
# !pip install boto3
# !pip install aws-kinesis-agg
# !pip install s3fs
# Out:
# Requirement already satisfied: boto3 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (1.34.131)
# Requirement already satisfied: botocore<1.35.0,>=1.34.131 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from boto3) (1.34.131)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.131->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.131->boto3) (2.2.2)
# Requirement already satisfied: six>=1.5 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.131->boto3) (1.16.0)
# Collecting aws-kinesis-agg
#   Using cached aws_kinesis_agg-1.2.3-py3-none-any.whl.metadata (16 kB)
# Collecting protobuf (from aws-kinesis-agg)
#   Using cached protobuf-5.27.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Using cached aws_kinesis_agg-1.2.3-py3-none-any.whl (22 kB)
# Using cached protobuf-5.27.2-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
# Installing collected packages: protobuf, aws-kinesis-agg
# Successfully installed aws-kinesis-agg-1.2.3 protobuf-5.27.2
# Requirement already satisfied: s3fs in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (2024.6.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from s3fs) (2.13.1)
# Requirement already satisfied: fsspec==2024.6.0.* in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from s3fs) (2024.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from s3fs) (3.9.5)
# Requirement already satisfied: botocore<1.34.132,>=1.34.70 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.131)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.2)
# Requirement already satisfied: idna>=2.0 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)
# Requirement already satisfied: six>=1.5 in /home/bcombs/miniconda3/envs/notebook_env/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)

# %% [markdown]
# **Make sure to create an `aws.cfg` file and upload it here**
#
# aws.cfg example:
#
# ```
# [AWS]
# aws_access_key_id = youraccesskey
# aws_secret_access_key = yoursecretkey
# region_name=us-east-1
# ```
# Make sure to change the values to match yours.

# %%
import boto3
import json
import time
import pandas as pd
import configparser

# Read AWS credentials from config file
config = configparser.ConfigParser()
config.read('aws.cfg')

aws_access_key_id = config['AWS']['aws_access_key_id']
aws_secret_access_key = config['AWS']['aws_secret_access_key']
region_name = config['AWS']['region_name']

# %%
# Initialize the boto3 client with credentials from config file
kinesis_client = boto3.client(
    'kinesis',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# %%
def produce(stream_name, data, partition_key):
    try:
        # Convert timestamps to strings
        for key in data:
            if isinstance(data[key], pd.Timestamp):
                data[key] = data[key].isoformat()
                # using the put_record method to push the stream
        response = kinesis_client.put_record(
            StreamName=stream_name,
            Data=json.dumps(data),
            PartitionKey=partition_key
        )
        return response
    except Exception as e:
        print(f"Error producing record: {e}")

# this function takes 5 records at a time and streams every 2-seconds
def stream_data(df, stream_name):
    for i in range(0, len(df), 5):
        records = df.iloc[i:i+5].to_dict(orient='records')
        for record in records:
            partition_key = str(record['tpep_pickup_datetime'])  # Use a valid column as the partition key

            # call the produce function
            produce(stream_name, record, partition_key)
        print(f"Sent {len(records)} records to Kinesis")
        time.sleep(2)

# %%
if __name__ == "__main__":
    stream_name = 'ben-stream'
    # Reading the yellow_taxis parquet file and stream it
    df = pd.read_parquet('s3://techcatalyst-public/yellow_tripdata_2024-01.parquet',
                     storage_options={
                      'key': aws_access_key_id,
                     'secret': aws_secret_access_key,
                     })
    stream_data(df, stream_name)
# Out:
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Error producing record: An error occurred (ResourceNotFoundException) when calling the PutRecord operation: Stream ben-stream under account 535146832369 not found.
# Sent 5 records to Kinesis
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       3 # Reading the yellow_taxis parquet file and stream it
#       4 df = pd.read_parquet('s3://techcatalyst-public/yellow_tripdata_2024-01.parquet',
#       5                  storage_options={
#       6                   'key': aws_access_key_id,
#       7                  'secret': aws_secret_access_key,
#       8                  })
# ----> 9 stream_data(df, stream_name)
#
# Cell In[8], line 27, in stream_data(df, stream_name)
#      25     produce(stream_name, record, partition_key)
#      26 print(f"Sent {len(records)} records to Kinesis")
# ---> 27 time.sleep(2)
#
# KeyboardInterrupt:
